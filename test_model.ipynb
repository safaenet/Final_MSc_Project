# %%
import os
import cv2
import torch
from torchvision import transforms
from prototypical_net import ConvNet
from PIL import Image
import random
from detect_object_multiscale import detect_object_multiscale
from matplotlib import pyplot as plt
from datetime import datetime
import re

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
patch_sizes=[84, 96, 112, 128]
stride=20
extensions=(".jpg", ".jpeg", ".png")
# Load model
model = ConvNet().to(device)
# model.load_state_dict(torch.load("saved_models/protonet_class_independent.pth"))
model.load_state_dict(torch.load("saved_models/prototypical_net_model.pth"))
model.eval()
# Out:
# ConvNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (12): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# ...

# %% [markdown]
# ### Transforms

# %%
# Transforms
transform = transforms.Compose([
    transforms.Resize((100, 100)),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3),
])

# %%
workspace_path = "images/workspace-images-manual/workspace30.png"
target_class = "carrot"

support_dir = os.path.join("images/support-images-augmented", target_class)
support_paths = [
    os.path.join(support_dir, f)
    for f in os.listdir(support_dir)
    if f.lower().endswith(extensions)
]

# Select up to 10 random support images (or fewer if not enough)
selected_paths = random.sample(support_paths, k=min(10, len(support_paths)))

# Load, transform, and embed all support images
embeddings = []
for path in selected_paths:
    img = Image.open(path).convert("RGB")
    tensor = transform(img).unsqueeze(0).to(device)
    with torch.no_grad():
        emb = model(tensor)
        embeddings.append(emb)

# Compute average embedding = class prototype
support_embedding = torch.mean(torch.stack(embeddings), dim=0)

# Load and process workspace image
workspace = cv2.imread(workspace_path)
workspace = cv2.cvtColor(workspace, cv2.COLOR_BGR2RGB)

# %%
detected_list = detect_object_multiscale(
    model=model,
    support_path_list=support_paths,
    workspace_path=workspace_path,
    patch_sizes=patch_sizes,
    stride=stride,
    device=device,
    
    distance=4, # Last good values. (normal model)
    threshold=0.0,
    confidence=0.6
    
    # distance=4, # Last good values. (protonet)
    # threshold=0.0,
    # confidence=0.75
)
detected_list
# Out:
# [{'location': (204, 84),
#   'distance': 0.22562041878700256,
#   'patch_size': 128,
#   'confidence': 0.8159132996410917},
#  {'location': (464, 204),
#   'distance': 0.3037513792514801,
#   'patch_size': 128,
#   'confidence': 0.7670174052464879},
#  {'location': (216, 456),
#   'distance': 0.32431912422180176,
#   'patch_size': 112,
#   'confidence': 0.7551050058177038},
#  {'location': (268, 308),
#   'distance': 0.34352895617485046,
#   'patch_size': 96,
#   'confidence': 0.7443084835678505},
#  {'location': (544, 384),
#   'distance': 0.3449554443359375,
#   'patch_size': 128,
#   'confidence': 0.7435190542640936},
#  {'location': (48, 288),
#   'distance': 0.35728922486305237,
#   'patch_size': 96,
#   'confidence': 0.7367626454861881},
#  {'location': (704, 104),
#   'distance': 0.365406334400177,
#   'patch_size': 128,
#   'confidence': 0.7323827162698054}]

# %%
print(f"Number of detected objects: {len(detected_list)}")
# Out:
# Number of detected objects: 7

# %%
if detected_list == []:
    print("Object not detected on the workspace.")
else:
    for loc in detected_list:
        x, y = loc['location']
        cv2.circle(workspace, (x, y), 5, (255, 250, 0), 2)
        # Write coordinates near the circle
        text = f"({x},{y})"
        cv2.putText(workspace, text, (x + 5, y - 5), 
                    fontFace=cv2.FONT_HERSHEY_SIMPLEX, 
                    fontScale=0.4, color=(255, 250, 0), thickness=1, lineType=cv2.LINE_AA)
    
    # Create directory
    os.makedirs("results", exist_ok=True)

    # Save before showing
    current_time = datetime.now()
    timestamp = current_time.strftime("%Y%m%d%H%M%S")
    save_result_image_filename = f"results/{timestamp} - {target_class}.png"
    cv2.imwrite(save_result_image_filename, cv2.cvtColor(workspace, cv2.COLOR_RGB2BGR))

    print(f"Saved to {save_result_image_filename}")
    
    plt.imshow(workspace)
    plt.xticks([0, 200, 400, 600, 800])
    plt.yticks([0, 150, 300, 450, 600])
    plt.show()
# Out:
# Saved to results/20250812120651 - carrot.png

# %% [markdown]
# ##### Generate GCode script

# %%
header = [
    "; G-code Simulation",
    "; Generated by MSc Project - Safa Dana",
    f"; Task: Pick and place '{target_class}'",
    "; Generated at: " + current_time.strftime('%Y-%m-%d %H:%M:%S'),
    ""
]

# Call the generator
from generate_gcode import generate_gcode_script_with_z
locations = [location['location'] for location in detected_list]
destination_xy = (0, 0)  # Example destination coordinates
scale = 0.5  # Example scale factor
commands = generate_gcode_script_with_z(target_class, locations, destination_xy, scale)
commands = header + commands
save_result_gcode_filename = f"results/{timestamp} - {target_class}.gcode"

# Save to a .gcode file
with open(save_result_gcode_filename, "w") as f:
    for cmd in commands:
        f.write(cmd + "\n")
        
print(f"Saved to {save_result_gcode_filename}")
# Out:
# Saved to results/20250812120651 - carrot.gcode

# %%
x_vals, y_vals = [], []
annotations = []
max_y_mm = 600 * scale

for cmd in commands:
    if cmd.startswith("G0"):
        parts = cmd.split()
        x = y = None
        for p in parts:
            if p.startswith("X"):
                x = float(p[1:])
            elif p.startswith("Y"):
                y = float(p[1:])
        if x is not None and y is not None:
            flipped_x = x  # keep as is (0 at left)
            flipped_y = max_y_mm - y  # flip Y (0 at top)
            x_vals.append(flipped_x)
            y_vals.append(flipped_y)
            annotations.append(cmd)

y_vals = [max_y_mm - y for y in y_vals]
# Plot path
# plt.figure(figsize=(8, 6))
fig, ax = plt.subplots()
ax.xaxis.set_label_position('top')
ax.xaxis.tick_top()
plt.xticks([0, 200 * scale, 400 * scale, 600 * scale, 800 * scale])
plt.yticks([0, 150 * scale, 300 * scale, 450 * scale, 600 * scale])
plt.plot(x_vals, y_vals, marker='o', linestyle='-', color='blue')
plt.title("Simulated Robotic Arm Movement")
plt.xlabel("X (mm)")
plt.ylabel("Y (mm)")
plt.grid(True)

# Annotate each step
for i, (x, y) in enumerate(zip(x_vals, y_vals)):
    plt.text(x + 1, y + 1, f"{i+1}", fontsize=8)
plt.gca().invert_yaxis()
plt.show()

# %%
# Convert screen size to mm
screen_width_mm = 800 * scale
screen_height_mm = 600 * scale

# Split text into lines
gcode_lines = commands

# Extract X, Y, Z positions from G-code
positions = []
for line in gcode_lines:
    match = re.search(r'G0 X([\d\.\-]+) Y([\d\.\-]+)(?: Z([\d\.\-]+))?', line)
    if match:
        x, y, z = match.groups()
        x = float(x)
        y = float(y)
        z = float(z) if z else None
        positions.append((x, y, z))

# Plotting the movements
fig, ax = plt.subplots()
prev_x, prev_y = None, None
for i, (x, y, z) in enumerate(positions):
    ax.plot(x, y, 'bo')  # Point
    ax.text(x + 1, y + 1, f"{i+1}", fontsize=8)
    if prev_x is not None and prev_y is not None:
        ax.plot([prev_x, x], [prev_y, y], 'r-')  # Line
    prev_x, prev_y = x, y

# Set screen dimensions
ax.set_xlim(0, screen_width_mm)
ax.set_ylim(0, screen_height_mm)
ax.set_xlabel("X (mm)")
ax.set_ylabel("Y (mm)")
ax.set_title("Robot Movement Path (Simulated Screen in mm)")
ax.grid(True)
ax.set_aspect('equal', adjustable='box')
plt.show()
